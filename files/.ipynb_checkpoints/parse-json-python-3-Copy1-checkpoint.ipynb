# %% [markdown]
# # Parse Nirvana JSON output in python
#
# Nirvana outputs a single JSON annotation file for a single input VCF file. The output file contains a single [JSON object](https://www.w3schools.com/js/js_json_objects.asp) to represent the annotations of all input VCF variants. The JSON file format can be found in the [documentation](https://illumina.github.io/NirvanaDocumentation/file-formats/nirvana-json-file-format).
#
# A [sample JSON file](https://github.com/Illumina/NirvanaDocumentation/blob/master/static/files/ceph_trio_test.json.gz) of the CEPH trio (NA12878, NA12891, and NA12892) can be downloaded from the [NirvanaDocumention](https://github.com/Illumina/NirvanaDocumentation/tree/master/static/files) git repo.
#
# This notebook demonstrates how you can parse this sample JSON file in python and retrieves the annotation data.
#
# ## Read Nirvana JSON output by lines
#
# Even though the Nirvana JSON output is a single JSON object, different JSON object fields are written in different lines for memory efficient reading.
#
# The first line in the JSON file is the `header` line:
#
# ```json
# {"header":{"annotator":"Nirvana
# ...
# ,"positions":[
# ```
# Followed by the `positions` lines:
#
# ```json
# {"chromosome":"chr21","position":9975027,"refAllele":"C","altAlleles":["G"],"quality":102.47,"filters":["PASS"],"fisherStrandBias":0.727,"mappingQuality":43.11,"cytogeneticBand":"21p11.2","samples":,
# ...
# ```
#
# After the `positions` lines, there are the `genes` lines, which are optional if there is no overlapping gene of the input VCF variants (3 lines for 2 genes in the example):
#
# ```json
# ],"genes":[
# {"name":"ABCC13","omim":[{"mimNumber":608835,"geneName":"ATP-binding cassette, subfamily C, member 13","description":"ABCC13 belongs to a large family of ATP-binding cassette (ABC) transporters that play important roles as membrane transporters or ion channel modulators. However, ABCC13 is a truncated protein that lacks critical ATP-binding motifs and is unlikely to be a functional transporter (Yabuuchi et al., 2002)."}]},
# ```
#
# Finally, the last line of the JSON file are two brackets to complete the JSON object structure:
#
# ```json
# ]}
# ```

# %% [markdown]
# ## Install requirements

# %%
# !pip3 install pydantic ijson polars
# Out:
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/site-packages (2.5.2)
# Requirement already satisfied: ijson in /usr/local/lib/python3.11/site-packages (3.2.3)
# Collecting polars
#   Downloading polars-0.19.19-cp38-abi3-macosx_10_12_x86_64.whl (26.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 22.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.11/site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /usr/local/lib/python3.11/site-packages (from pydantic) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.11/site-packages (from pydantic) (4.8.0)
# Installing collected packages: polars
# Successfully installed polars-0.19.19
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import gzip
import ijson
import functools

from typing import Any, Dict, List, Optional


import polars as pd
import pydantic

# pd.set_option('display.max_columns', None)
pd.Config(tbl_rows=50)

class AnnotatedData:
    def __init__(self, filename: str):
        self._filename = filename
        
        
        for key in ("annotator", "genomeAssembly", "creationTime"):
            print(f"{key}: {self.header[key]}")     
        
    @property
    def header(self) -> dict:
        with gzip.open(self._filename, 'r') as f:
            return next(ijson.items(f, "header"))
    
    @property
    def data_sources(self):
        return pd.DataFrame(self.header["dataSources"]).sort(by="name")
        
    @property
    def genes(self) -> pd.DataFrame:
        with gzip.open(self._filename, 'r') as f:
            # return pd.json_normalize(ijson.items(f, "genes.item"))
            return pd.DataFrame(ijson.items(f, "genes.item"))
        
    @property
    def positions(self) -> list:
        f =  gzip.open(self._filename, 'r')
        return ijson.items(f, "positions.item")


    def get_annotation(self, chromosome: str, position: int) -> dict:
        
        return next(
            (
                position_item for position_item in self.positions
                if chromosome == position_item.get("chromosome") and \
                position == position_item.get("position")
            ),
            None
        )
    
    @staticmethod
    def multiple_to_df(items: list, key: str = ""):
        return pd.concat((item.to_df(key) for item in items))
    
class BaseClass(pydantic.BaseModel):
    @staticmethod
    def _get_nested_value(dictionary, keys):
        keys = keys.split('.')
        for key in keys:
            print(dictionary)
            if isinstance(dictionary, dict):
                dictionary = dictionary.get(key)
            else:
                return None
        return dictionary
        
    def get_top_level(self):
        return pd.DataFrame(self.get_top_level_dict()).unnest()
    
    def get_top_level_dict(self):
        raise NotImplementedError
    
    def to_df(self, key: str = "") -> pd.DataFrame:
        if not key:
            return pd.DataFrame(self.model_dump()).unnest()
                        
        # values = self._get_nested_value(self.model_dump(), key)
        values = self.model_dump().get(key)
        
        if isinstance(values, list):
            merged = [self.get_top_level_dict() | value for value in values]
        else:
            merged = [self.get_top_level_dict() | {key: values}]
        
        # return pd.json_normalize(merged)
        return pd.DataFrame(merged).unnest()
    
class Transcript(BaseClass):
    model_config = pydantic.ConfigDict(extra='allow') 
    transcript: str
    source: str
    bioType: Optional[str]
    geneId: Optional[str]
    hgnc: Optional[str]
    consequence: Optional[List[str]]
    impact: Optional[str]
    isCanonical: Optional[bool]
    
    def get_top_level_dict(self):
        return dict(zip(
            ("transcript", "isCanonical"),
            (self.transcript, self.isCanonical)
        ))
    
    
class Variant(BaseClass):
    model_config = pydantic.ConfigDict(extra='allow') 
    vid: str
    chromosome: str
    begin: int
    end: int
    refAllele: str
    altAllele: str
    variantType: Optional[str]
    hgvsg: Optional[str]
    phylopScore: Optional[float]
    phyloPPrimateScore: Optional[float]
    transcripts: Optional[List[Transcript]] = None
        
    def get_top_level_dict(self):
        return dict(zip(
            ("chromosome", "begin", "end", "refAllele", "altAllele", "hgvsg"),
            (self.chromosome, self.begin, self.end, self.refAllele, self.altAllele, self.hgvsg)
        ))
    
    
class Position(BaseClass):
    model_config = pydantic.ConfigDict(extra='allow') 
    chromosome: str
    position: int
    refAllele: str
    altAlleles: List[str]
    filters: List[str]
    mappingQuality: float
    cytogeneticBand: str
    vcfInfo: Dict[str, Any]
    samples: List
    variants: List[Variant]
    
    def get_top_level_dict(self):
        return dict(zip(
            ("chromosome", "position", "refAllele", "altAlleles", "filters", "mappingQuality", "cyatogeneticBand", "vcfInfo"),
            (self.chromosome, self.position, self.refAllele, self.altAlleles, self.filters, self.mappingQuality, self.cytogeneticBand, self.vcfInfo)
        ))

# %% [markdown]
# ## Header

# %%
filename = "annotated_38.json.gz"
annotated_data = AnnotatedData(filename=filename)
# Out:
# annotator: Illumina Connected Annotations 3.22.0
# genomeAssembly: GRCh38
# creationTime: 2023-12-07 14:15:54

# %%
annotated_data.data_sources
# Out:
# shape: (32, 4)
# ┌────────────────────────────┬───────────────────────────┬───────────────────────────┬─────────────┐
# │ name                       ┆ version                   ┆ description               ┆ releaseDate │
# │ ---                        ┆ ---                       ┆ ---                       ┆ ---         │
# │ str                        ┆ str                       ┆ str                       ┆ str         │
# ╞════════════════════════════╪═══════════════════════════╪═══════════════════════════╪═════════════╡
# │ 1000 Genomes Project       ┆ Phase 3 v3plus            ┆ A public catalogue of     ┆ 2013-05-27  │
# │                            ┆                           ┆ human vari…               ┆             │
# │ 1000 Genomes Project (SV)  ┆ Phase 3 v5a               ┆ A public catalogue of     ┆ 2013-05-27  │
# │                            ┆                           ┆ human vari…               ┆             │
# │ COSMIC                     ┆ 96                        ┆ resource for exploring    ┆ 2022-05-31  │
# │                            ┆                           ┆ the impac…                ┆             │
# │ COSMIC gene fusions        ┆ 96                        ┆ manually curated somatic  ┆ 2023-11-07  │
# │                            ┆                           ┆ gene fu…                  ┆             │
# │ CancerHotspots             ┆ 2017                      ┆ A resouce for             ┆ 2017-01-01  │
# │                            ┆                           ┆ statistically sign…       ┆             │
# │ ClinGen                    ┆ 20160414                  ┆ null                      ┆ 2016-04-14  │
# │ ClinGen Dosage Sensitivity ┆ 20231105                  ┆ Dosage sensitivity map    ┆ 2023-11-05  │
# │ Map                        ┆                           ┆ from Clin…                ┆             │
# │ ClinGen disease validity   ┆ 20231105                  ┆ Disease validity          ┆ 2023-11-05  │
# │ curatio…                   ┆                           ┆ curations from …          ┆             │
# │ ClinVar                    ┆ 20231028                  ┆ A freely accessible,      ┆ 2023-11-05  │
# │                            ┆                           ┆ public arch…              ┆             │
# │ Cosmic Cancer Gene Census  ┆ 97                        ┆ Cosmic Cancer Gene Census ┆ 2022-11-29  │
# │                            ┆                           ┆ catalo…                   ┆             │
# │ DANN                       ┆ 20200205                  ┆ Pathogenicity scores of   ┆ 2020-02-05  │
# │                            ┆                           ┆ missense…                 ┆             │
# │ DECIPHER                   ┆ 201509                    ┆ Common copy-number        ┆ 2015-09-01  │
# │                            ┆                           ┆ variants and …            ┆             │
# │ Ensembl                    ┆ 110                       ┆ Ensembl GRCh38 Release    ┆ 2023-04-27  │
# │ FusionCatcher              ┆ 1.33                      ┆ known germline and        ┆ 2020-12-22  │
# │                            ┆                           ┆ somatic gene …            ┆             │
# │ GME                        ┆ 20160618                  ┆ Greater Middle Eastern    ┆ 2016-06-18  │
# │                            ┆                           ┆ Variome a…                ┆             │
# │ Gerp                       ┆ 20110522                  ┆ GERP identifies           ┆ 2011-05-22  │
# │                            ┆                           ┆ constrained elem…         ┆             │
# │ MITOMAP                    ┆ 20200819                  ┆ Small variants in the     ┆ 2020-08-19  │
# │                            ┆                           ┆ MITOMAP hu…               ┆             │
# │ MITOMAP_SV                 ┆ 20200819                  ┆ Large structural variants ┆ 2020-08-19  │
# │                            ┆                           ┆ in the…                   ┆             │
# │ MitochondrialHeteroplasmy  ┆ 20180410                  ┆ Variant read frequency    ┆ 2020-05-21  │
# │                            ┆                           ┆ percentil…                ┆             │
# │ OMIM                       ┆ 20231105                  ┆ An Online Catalog of      ┆ 2023-11-05  │
# │                            ┆                           ┆ Human Genes…              ┆             │
# │ PhyloPPrimate              ┆ 1.0                       ┆ PhyloPPrimate identifies  ┆ 2023-11-29  │
# │                            ┆                           ┆ primate…                  ┆             │
# │ PrimateAI-3D               ┆ 1.0                       ┆ PrimateAI-3D is a         ┆ 2023-06-02  │
# │                            ┆                           ┆ deep-learning …           ┆             │
# │ REVEL                      ┆ 20200205                  ┆ Pathogenicity scores of   ┆ 2020-02-05  │
# │                            ┆                           ┆ missense…                 ┆             │
# │ RefSeq                     ┆ GCF_000001405.40-RS_2023_ ┆ NCBI Homo sapiens         ┆ 2023-03-21  │
# │                            ┆ 03                        ┆ Annotation Rel…           ┆             │
# │ SpliceAI                   ┆ 1.3                       ┆ SpliceAI scores,          ┆ 2019-10-04  │
# │                            ┆                           ┆ distances, etc.           ┆             │
# │ TOPMed                     ┆ freeze_5                  ┆ Allele frequencies from   ┆ 2017-08-28  │
# │                            ┆                           ┆ TOPMed d…                 ┆             │
# │ dbSNP                      ┆ 156                       ┆ Identifiers for observed  ┆ 2023-09-28  │
# │                            ┆                           ┆ variant…                  ┆             │
# │ gnomAD                     ┆ 3.1.2                     ┆ Allele frequencies from   ┆ 2021-10-22  │
# │                            ┆                           ┆ Genome A…                 ┆             │
# │ gnomAD_LCR                 ┆ 2.1                       ┆ Low complexity regions    ┆ 2019-04-10  │
# │                            ┆                           ┆ from gnom…                ┆             │
# │ gnomAD_SV                  ┆ 2.1                       ┆ A structural variation    ┆ 2020-08-20  │
# │                            ┆                           ┆ reference…                ┆             │
# │ gnomAD_gene_scores         ┆ 2.1                       ┆ Gene Loss of function     ┆ 2018-10-17  │
# │                            ┆                           ┆ scores fro…               ┆             │
# │ phyloP                     ┆ hg38                      ┆ 20 way conservation score ┆ 2015-04-17  │
# │                            ┆                           ┆ betwee…                   ┆             │
# └────────────────────────────┴───────────────────────────┴───────────────────────────┴─────────────┘

# %% [markdown]
# ## Genes

# %%
annotated_data.genes
# Out:
# thread '<unnamed>' panicked at crates/polars-core/src/frame/row/av_buffer.rs:249:85:
# called `Result::unwrap()` on an `Err` value: ComputeError(ErrString("unable to losslessly convert any-value of scale 60 to scale 3"))
# ---------------------------------------------------------------------------
# PanicException                            Traceback (most recent call last)
# Cell In[392], line 1
# ----> 1 annotated_data.genes
#
# Cell In[389], line 35, in AnnotatedData.genes(self)
#      31 @property
#      32 def genes(self) -> pd.DataFrame:
#      33     with gzip.open(self._filename, 'r') as f:
#      34         # return pd.json_normalize(ijson.items(f, "genes.item"))
# ---> 35         return pd.DataFrame(ijson.items(f, "genes.item"))
#
# File /usr/local/lib/python3.11/site-packages/polars/dataframe/frame.py:400, in DataFrame.__init__(self, data, schema, schema_overrides, orient, infer_schema_length, nan_to_null)
#     395     self._df = pandas_to_pydf(
#     396         data, schema=schema, schema_overrides=schema_overrides
#     397     )
#     399 elif not isinstance(data, Sized) and isinstance(data, (Generator, Iterable)):
# --> 400     self._df = iterable_to_pydf(
#     401         data,
#     402         schema=schema,
#     403         schema_overrides=schema_overrides,
#     404         orient=orient,
#     405         infer_schema_length=infer_schema_length,
#     406     )
#     407 else:
#     408     raise TypeError(
#     409         f"DataFrame constructor called with unsupported type {type(data).__name__!r}"
#     410         " for the `data` parameter"
#     411     )
#
# File /usr/local/lib/python3.11/site-packages/polars/utils/_construction.py:1664, in iterable_to_pydf(data, schema, schema_overrides, orient, chunk_size, infer_schema_length)
#    1662 if not values:
#    1663     break
# -> 1664 frame_chunk = to_frame_chunk(values, original_schema)
#    1665 if df is None:
#    1666     df = frame_chunk
#
# File /usr/local/lib/python3.11/site-packages/polars/utils/_construction.py:1638, in iterable_to_pydf.<locals>.to_frame_chunk(values, schema)
#    1637 def to_frame_chunk(values: list[Any], schema: SchemaDefinition | None) -> DataFrame:
# -> 1638     return pl.DataFrame(
#    1639         data=values,
#    1640         schema=schema,
#    1641         orient="row",
#    1642         infer_schema_length=infer_schema_length,
#    1643     )
#
# File /usr/local/lib/python3.11/site-packages/polars/dataframe/frame.py:368, in DataFrame.__init__(self, data, schema, schema_overrides, orient, infer_schema_length, nan_to_null)
#     360     self._df = dict_to_pydf(
#     361         data,
#     362         schema=schema,
#     363         schema_overrides=schema_overrides,
#     364         nan_to_null=nan_to_null,
#     365     )
#     367 elif isinstance(data, (list, tuple, Sequence)):
# --> 368     self._df = sequence_to_pydf(
#     369         data,
#     370         schema=schema,
#     371         schema_overrides=schema_overrides,
#     372         orient=orient,
#     373         infer_schema_length=infer_schema_length,
#     374     )
#     375 elif isinstance(data, pl.Series):
#     376     self._df = series_to_pydf(
#     377         data, schema=schema, schema_overrides=schema_overrides
#     378     )
#
# File /usr/local/lib/python3.11/site-packages/polars/utils/_construction.py:940, in sequence_to_pydf(data, schema, schema_overrides, orient, infer_schema_length)
#     937 if len(data) == 0:
#     938     return dict_to_pydf({}, schema=schema, schema_overrides=schema_overrides)
# --> 940 return _sequence_to_pydf_dispatcher(
#     941     data[0],
#     942     data=data,
#     943     schema=schema,
#     944     schema_overrides=schema_overrides,
#     945     orient=orient,
#     946     infer_schema_length=infer_schema_length,
#     947 )
#
# File /usr/local/Cellar/python@3.11/3.11.2_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     905 if not args:
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File /usr/local/lib/python3.11/site-packages/polars/utils/_construction.py:1159, in _sequence_of_dict_to_pydf(first_element, data, schema, schema_overrides, infer_schema_length, **kwargs)
#    1151 column_names, schema_overrides = _unpack_schema(
#    1152     schema, schema_overrides=schema_overrides
#    1153 )
#    1154 dicts_schema = (
#    1155     include_unknowns(schema_overrides, column_names or list(schema_overrides))
#    1156     if column_names
#    1157     else None
#    1158 )
# -> 1159 pydf = PyDataFrame.read_dicts(
#    1160     data, infer_schema_length, dicts_schema, schema_overrides
#    1161 )
#    1163 # TODO: we can remove this `schema_overrides` block completely
#    1164 #  once https://github.com/pola-rs/polars/issues/11044 is fixed
#    1165 if schema_overrides:
#
# PanicException: called `Result::unwrap()` on an `Err` value: ComputeError(ErrString("unable to losslessly convert any-value of scale 60 to scale 3"))

# %% [markdown]
# ## Positions

# %%
position = Position.model_validate(annotated_data.get_annotation("chr21", 5228221))
position.to_df()
# Out:
#   chromosome  position refAllele altAlleles filters  mappingQuality
# 0      chr21   5228221         G        [T]  [PASS]           75.75  \
#
#   cytogeneticBand                                            samples
# 0           21p12  [{'genotype': '0/0', 'variantFrequencies': [0....  \
#
#                                             variants vcfInfo.DP
# 0  [{'vid': '21-5228221-G-T', 'chromosome': 'chr2...       1004

# %%
position.to_df(key="variants")
# Out:
#   chromosome  position refAllele altAlleles filters  mappingQuality
# 0      chr21   5228221         G        [T]  [PASS]           75.75  \
#
#   cyatogeneticBand             vid    begin      end altAllele variantType
# 0            21p12  21-5228221-G-T  5228221  5228221         T         SNV  \
#
#                       hgvsg  phylopScore  phyloPPrimateScore
# 0  NC_000021.9:g.5228221G>T          0.2                 0.0  \
#
#                                          transcripts vcfInfo.DP
# 0  [{'transcript': 'ENST00000623753.1', 'source':...       1004

# %%
position.variants[0].to_df("transcripts")
# Out:
#   chromosome    begin      end refAllele altAllele                     hgvsg
# 0      chr21  5228221  5228221         G         T  NC_000021.9:g.5228221G>T  \
#
#           transcript   source bioType           geneId             hgnc
# 0  ENST00000623753.1  Ensembl  lncRNA  ENSG00000279669  ENSG00000279669  \
#
#                  consequence    impact  isCanonical
# 0  [downstream_gene_variant]  modifier         True

# %%
AnnotatedData.multiple_to_df(position.variants, key="transcripts")
# Out:
#   chromosome    begin      end refAllele altAllele                     hgvsg
# 0      chr21  5228221  5228221         G         T  NC_000021.9:g.5228221G>T  \
#
#           transcript   source bioType           geneId             hgnc
# 0  ENST00000623753.1  Ensembl  lncRNA  ENSG00000279669  ENSG00000279669  \
#
#                  consequence    impact  isCanonical
# 0  [downstream_gene_variant]  modifier         True

# %%
position = Position.model_validate(annotated_data.get_annotation("chr21", 5222289))
position.get_top_level()
# Out:
#   chromosome  position refAllele altAlleles                           filters
# 0      chr21   5222289         C        [T]  [mapping_quality, weak_evidence]  \
#
#    mappingQuality cyatogeneticBand vcfInfo.DP
# 0            49.7            21p12        749

# %%
position.to_df()
# Out:
#   chromosome  position refAllele altAlleles                           filters
# 0      chr21   5222289         C        [T]  [mapping_quality, weak_evidence]  \
#
#    mappingQuality cytogeneticBand
# 0            49.7           21p12  \
#
#                                              samples
# 0  [{'genotype': '0/0', 'variantFrequencies': [0....  \
#
#                                             variants vcfInfo.DP
# 0  [{'vid': '21-5222289-C-T', 'chromosome': 'chr2...        749

# %%
position.to_df("cytogeneticBand")
# Out:
#   chromosome  position refAllele altAlleles                           filters
# 0      chr21   5222289         C        [T]  [mapping_quality, weak_evidence]  \
#
#    mappingQuality cyatogeneticBand cytogeneticBand vcfInfo.DP
# 0            49.7            21p12           21p12        749

# %%
position.to_df("variants")
# Out:
#   chromosome  position refAllele altAlleles                           filters
# 0      chr21   5222289         C        [T]  [mapping_quality, weak_evidence]  \
#
#    mappingQuality cyatogeneticBand             vid    begin      end
# 0            49.7            21p12  21-5222289-C-T  5222289  5222289  \
#
#   altAllele variantType                     hgvsg  phylopScore
# 0         T         SNV  NC_000021.9:g.5222289C>T         -0.2  \
#
#    phyloPPrimateScore transcripts           dbsnp vcfInfo.DP  gnomad.coverage
# 0               0.074        None  [rs1366179382]        749                3  \
#
#   gnomad.allAf  gnomad.allAn  gnomad.allAc  gnomad.allHc gnomad.afrAf
# 0     0.000502        149274            75             0     0.001704  \
#
#    gnomad.afrAn  gnomad.afrAc  gnomad.afrHc gnomad.amrAf  gnomad.amrAn
# 0         40502            69             0     0.000067         14966  \
#
#    gnomad.amrAc  gnomad.amrHc  gnomad.easAf  gnomad.easAn  gnomad.easAc
# 0             1             0             0          5022             0  \
#
#    gnomad.easHc  gnomad.finAf  gnomad.finAn  gnomad.finAc  gnomad.finHc
# 0             0             0         10430             0             0  \
#
#   gnomad.nfeAf  gnomad.nfeAn  gnomad.nfeAc  gnomad.nfeHc  gnomad.asjAf
# 0     0.000075         66950             5             0             0  \
#
#    gnomad.asjAn  gnomad.asjAc  gnomad.asjHc  gnomad.sasAf  gnomad.sasAn
# 0          3438             0             0             0          4734  \
#
#    gnomad.sasAc  gnomad.sasHc  gnomad.othAf  gnomad.othAn  gnomad.othAc
# 0             0             0             0          2024             0  \
#
#    gnomad.othHc gnomad.maleAf  gnomad.maleAn  gnomad.maleAc  gnomad.maleHc
# 0             0      0.000411          73006             30              0  \
#
#   gnomad.femaleAf  gnomad.femaleAn  gnomad.femaleAc  gnomad.femaleHc
# 0         0.00059            76268               45                0  \
#
#   gnomad.controlsAllAf  gnomad.controlsAllAn  gnomad.controlsAllAc
# 0             0.000565                 31850                    18  \
#
#   topmed.allAf  topmed.allAn  topmed.allAc  topmed.allHc  topmed.failedFilter
# 0     0.001091        125568           137             0                 True

# %% [markdown]
# # Parsing and Filtering

# %%
class Parser:
    def __init__(self, annotated_data: AnnotatedData):
        self.annotated_data = annotated_data
        
    def get_variants_above_gnomad_freq(
        self,
        frequency_key: str,
        frequency_threshold_low=float("-inf"),
        frequency_threshold_high=float("inf")
    ) -> list:
        positions = [
            Position.model_validate(position)
            for position in self.annotated_data.positions
            for variant in position.get("variants", {})
            if (freq := variant.get("gnomad", {}).get(frequency_key, None)) \
            and frequency_threshold_low < freq < frequency_threshold_high
        ]
        return positions
    
    def get_positions_with_cannonical_transcripts(self):   
        positions = [
            Position.model_validate(position)
            for position in self.annotated_data.positions
            for variant in position.get("variants", {})
            for transcript in variant.get("transcripts", [])
            if transcript.get("isCanonical")
        ]

        return positions
    
    def filter_transcripts_by_consequence(self, include=[], exclude=[]):
        positions = [
            Position.model_validate(position)
            for position in self.annotated_data.positions
            for variant in position.get("variants", {})
            for transcript in variant.get("transcripts", [])
            for consequence in transcript.get("consequence", [])
            if (not bool(include) or consequence in include) and consequence not in exclude
        ]
        return positions

# %% [markdown]
# ## Positions with Cannonical Transcripts only

# %%
parser = Parser(annotated_data)

# %%
positions = parser.get_positions_with_cannonical_transcripts()
len(list(positions))
# Out:
# 2472

# %%
Position.positions_to_df(positions, "variants")
# Out:
#    chromosome  position refAllele altAlleles
# 0       chr21   5228221         G        [T]  \
# 0       chr21   5232869         T        [G]
# 0       chr21   5243664         C        [T]
# 0       chr21   5243812         C        [T]
# 0       chr21   6367612         -    [CAATG]
# ..        ...       ...       ...        ...
# 0       chr21  46597114         C        [A]
# 0       chr21  46597227         A        [C]
# 0       chr21  46597227         A        [C]
# 0       chr21  46643510         T        [A]
# 0       chr21  46643510         T        [A]
#
#                                               filters  mappingQuality
# 0                                              [PASS]           75.75  \
# 0                       [base_quality, weak_evidence]           58.10
# 0   [mapping_quality, no_reliable_supporting_read,...           58.13
# 0                                              [PASS]          108.19
# 0                                    [filtered_reads]           21.70
# ..                                                ...             ...
# 0                                              [PASS]          219.26
# 0                       [base_quality, weak_evidence]          217.92
# 0                       [base_quality, weak_evidence]          217.92
# 0                       [base_quality, weak_evidence]          211.58
# 0                       [base_quality, weak_evidence]          211.58
#
#    cyatogeneticBand                 vid     begin       end altAllele
# 0             21p12      21-5228221-G-T   5228221   5228221         T  \
# 0             21p12      21-5232869-T-G   5232869   5232869         G
# 0             21p12      21-5243664-C-T   5243664   5243664         T
# 0             21p12      21-5243812-C-T   5243812   5243812         T
# 0             21p12  21-6367612-C-CAATG   6367613   6367612      AATG
# ..              ...                 ...       ...       ...       ...
# 0           21q22.3     21-46597114-C-A  46597114  46597114         A
# 0           21q22.3     21-46597227-A-C  46597227  46597227         C
# 0           21q22.3     21-46597227-A-C  46597227  46597227         C
# 0           21q22.3     21-46643510-T-A  46643510  46643510         A
# 0           21q22.3     21-46643510-T-A  46643510  46643510         A
#
#    variantType                             hgvsg phylopScore
# 0          SNV          NC_000021.9:g.5228221G>T         0.2  \
# 0          SNV          NC_000021.9:g.5232869T>G         0.5
# 0          SNV          NC_000021.9:g.5243664C>T         0.6
# 0          SNV          NC_000021.9:g.5243812C>T         0.4
# 0    insertion  NC_000021.9:g.6367616_6367619dup         NaN
# ..         ...                               ...         ...
# 0          SNV         NC_000021.9:g.46597114C>A         0.5
# 0          SNV         NC_000021.9:g.46597227A>C         0.6
# 0          SNV         NC_000021.9:g.46597227A>C         0.6
# 0          SNV         NC_000021.9:g.46643510T>A           0
# 0          SNV         NC_000021.9:g.46643510T>A           0
#
#    phyloPPrimateScore                                        transcripts
# 0                   0  [{'transcript': 'ENST00000623753.1', 'source':...  \
# 0                 NaN  [{'transcript': 'ENST00000623753.1', 'source':...
# 0               0.074  [{'transcript': 'ENST00000623753.1', 'source':...
# 0               0.074  [{'transcript': 'ENST00000623753.1', 'source':...
# 0                 NaN  [{'transcript': 'ENST00000615262.1', 'source':...
# ..                ...                                                ...
# 0              -0.072  [{'transcript': 'ENST00000291700.9', 'source':...
# 0               0.781  [{'transcript': 'ENST00000291700.9', 'source':...
# 0               0.781  [{'transcript': 'ENST00000291700.9', 'source':...
# 0              -0.603  [{'transcript': 'ENST00000451211.6', 'source':...
# 0              -0.603  [{'transcript': 'ENST00000451211.6', 'source':...
#
#    vcfInfo.DP                                  regulatoryRegions
# 0        1004                                                NaN  \
# 0         799                                                NaN
# 0         644  [{'id': 'ENSR00000140073', 'type': 'TF_binding...
# 0         514  [{'id': 'ENSR00000140073', 'type': 'TF_binding...
# 0         375                                                NaN
# ..        ...                                                ...
# 0         143                                                NaN
# 0         151                                                NaN
# 0         151                                                NaN
# 0         150  [{'id': 'ENSR00001057246', 'type': 'CTCF_bindi...
# 0         150  [{'id': 'ENSR00001057246', 'type': 'CTCF_bindi...
#
#     gnomad.coverage gnomad.failedFilter gnomad.allAf  gnomad.allAn
# 0               NaN                 NaN          NaN           NaN  \
# 0               NaN                 NaN          NaN           NaN
# 0               0.0                True            0      152310.0
# 0               0.0                True            0      152296.0
# 0              11.0                True     0.139262       20860.0
# ..              ...                 ...          ...           ...
# 0               NaN                 NaN          NaN           NaN
# 0               NaN                 NaN          NaN           NaN
# 0               NaN                 NaN          NaN           NaN
# 0               0.0                True     0.000021      141118.0
# 0               0.0                True     0.000021      141118.0
#
#     gnomad.allAc  gnomad.allHc gnomad.afrAf  gnomad.afrAn  gnomad.afrAc
# 0            NaN           NaN          NaN           NaN           NaN  \
# 0            NaN           NaN          NaN           NaN           NaN
# 0            0.0           0.0            0       41488.0           0.0
# 0            0.0           0.0            0       41480.0           0.0
# 0         2905.0           3.0     0.065393        2722.0         178.0
# ..           ...           ...          ...           ...           ...
# 0            NaN           NaN          NaN           NaN           NaN
# 0            NaN           NaN          NaN           NaN           NaN
# 0            NaN           NaN          NaN           NaN           NaN
# 0            3.0           0.0     0.000051       39060.0           2.0
# 0            3.0           0.0     0.000051       39060.0           2.0
#
#     gnomad.afrHc gnomad.amrAf  gnomad.amrAn  gnomad.amrAc  gnomad.amrHc
# 0            NaN          NaN           NaN           NaN           NaN  \
# 0            NaN          NaN           NaN           NaN           NaN
# 0            0.0            0       15294.0           0.0           0.0
# 0            0.0            0       15294.0           0.0           0.0
# 0            0.0     0.110881        1930.0         214.0           1.0
# ..           ...          ...           ...           ...           ...
# 0            NaN          NaN           NaN           NaN           NaN
# 0            NaN          NaN           NaN           NaN           NaN
# 0            NaN          NaN           NaN           NaN           NaN
# 0            0.0            0       14018.0           0.0           0.0
# 0            0.0            0       14018.0           0.0           0.0
#
#    gnomad.easAf  gnomad.easAn  gnomad.easAc  gnomad.easHc gnomad.finAf
# 0           NaN           NaN           NaN           NaN          NaN  \
# 0           NaN           NaN           NaN           NaN          NaN
# 0             0        5208.0           0.0           0.0            0
# 0             0        5206.0           0.0           0.0            0
# 0      0.108384         978.0         106.0           0.0     0.132432
# ..          ...           ...           ...           ...          ...
# 0           NaN           NaN           NaN           NaN          NaN
# 0           NaN           NaN           NaN           NaN          NaN
# 0           NaN           NaN           NaN           NaN          NaN
# 0      0.000232        4306.0           1.0           0.0            0
# 0      0.000232        4306.0           1.0           0.0            0
#
#     gnomad.finAn  gnomad.finAc  gnomad.finHc gnomad.nfeAf  gnomad.nfeAn
# 0            NaN           NaN           NaN          NaN           NaN  \
# 0            NaN           NaN           NaN          NaN           NaN
# 0        10632.0           0.0           0.0            0       68056.0
# 0        10628.0           0.0           0.0            0       68058.0
# 0          370.0          49.0           0.0     0.172472       12518.0
# ..           ...           ...           ...          ...           ...
# 0            NaN           NaN           NaN          NaN           NaN
# 0            NaN           NaN           NaN          NaN           NaN
# 0            NaN           NaN           NaN          NaN           NaN
# 0         7762.0           0.0           0.0            0       65358.0
# 0         7762.0           0.0           0.0            0       65358.0
#
#     gnomad.nfeAc  gnomad.nfeHc gnomad.asjAf  gnomad.asjAn  gnomad.asjAc
# 0            NaN           NaN          NaN           NaN           NaN  \
# 0            NaN           NaN          NaN           NaN           NaN
# 0            0.0           0.0            0        3472.0           0.0
# 0            0.0           0.0            0        3472.0           0.0
# 0         2159.0           2.0     0.087379         824.0          72.0
# ..           ...           ...          ...           ...           ...
# 0            NaN           NaN          NaN           NaN           NaN
# 0            NaN           NaN          NaN           NaN           NaN
# 0            NaN           NaN          NaN           NaN           NaN
# 0            0.0           0.0            0        3364.0           0.0
# 0            0.0           0.0            0        3364.0           0.0
#
#     gnomad.asjHc gnomad.sasAf  gnomad.sasAn  gnomad.sasAc  gnomad.sasHc
# 0            NaN          NaN           NaN           NaN           NaN  \
# 0            NaN          NaN           NaN           NaN           NaN
# 0            0.0            0        4838.0           0.0           0.0
# 0            0.0            0        4836.0           0.0           0.0
# 0            0.0     0.059756         820.0          49.0           0.0
# ..           ...          ...           ...           ...           ...
# 0            NaN          NaN           NaN           NaN           NaN
# 0            NaN          NaN           NaN           NaN           NaN
# 0            NaN          NaN           NaN           NaN           NaN
# 0            0.0            0        4110.0           0.0           0.0
# 0            0.0            0        4110.0           0.0           0.0
#
#    gnomad.othAf  gnomad.othAn  gnomad.othAc  gnomad.othHc gnomad.maleAf
# 0           NaN           NaN           NaN           NaN           NaN  \
# 0           NaN           NaN           NaN           NaN           NaN
# 0             0        2094.0           0.0           0.0             0
# 0             0        2094.0           0.0           0.0             0
# 0          0.16         300.0          48.0           0.0      0.127778
# ..          ...           ...           ...           ...           ...
# 0           NaN           NaN           NaN           NaN           NaN
# 0           NaN           NaN           NaN           NaN           NaN
# 0           NaN           NaN           NaN           NaN           NaN
# 0             0        1968.0           0.0           0.0             0
# 0             0        1968.0           0.0           0.0             0
#
#     gnomad.maleAn  gnomad.maleAc  gnomad.maleHc gnomad.femaleAf
# 0             NaN            NaN            NaN             NaN  \
# 0             NaN            NaN            NaN             NaN
# 0         74416.0            0.0            0.0               0
# 0         74406.0            0.0            0.0               0
# 0          8640.0         1104.0            0.0        0.147381
# ..            ...            ...            ...             ...
# 0             NaN            NaN            NaN             NaN
# 0             NaN            NaN            NaN             NaN
# 0             NaN            NaN            NaN             NaN
# 0         68068.0            0.0            0.0        0.000041
# 0         68068.0            0.0            0.0        0.000041
#
#     gnomad.femaleAn  gnomad.femaleAc  gnomad.femaleHc gnomad.controlsAllAf
# 0               NaN              NaN              NaN                  NaN  \
# 0               NaN              NaN              NaN                  NaN
# 0           77894.0              0.0              0.0                    0
# 0           77890.0              0.0              0.0                    0
# 0           12220.0           1801.0              3.0             0.123314
# ..              ...              ...              ...                  ...
# 0               NaN              NaN              NaN                  NaN
# 0               NaN              NaN              NaN                  NaN
# 0               NaN              NaN              NaN                  NaN
# 0           73050.0              3.0              0.0             0.000108
# 0           73050.0              3.0              0.0             0.000108
#
#     gnomad.controlsAllAn  gnomad.controlsAllAc           dbsnp topmed.allAf
# 0                    NaN                   NaN             NaN          NaN  \
# 0                    NaN                   NaN             NaN          NaN
# 0                32928.0                   0.0             NaN          NaN
# 0                32922.0                   0.0             NaN          NaN
# 0                 5190.0                 640.0  [rs1234944247]     0.078897
# ..                   ...                   ...             ...          ...
# 0                    NaN                   NaN             NaN          NaN
# 0                    NaN                   NaN             NaN          NaN
# 0                    NaN                   NaN             NaN          NaN
# 0                27846.0                   3.0  [rs1601921720]          NaN
# 0                27846.0                   3.0  [rs1601921720]          NaN
#
#     topmed.allAn  topmed.allAc  topmed.allHc topmed.failedFilter
# 0            NaN           NaN           NaN                 NaN  \
# 0            NaN           NaN           NaN                 NaN
# 0            NaN           NaN           NaN                 NaN
# 0            NaN           NaN           NaN                 NaN
# 0       125568.0        9907.0           0.0                True
# ..           ...           ...           ...                 ...
# 0            NaN           NaN           NaN                 NaN
# 0            NaN           NaN           NaN                 NaN
# 0            NaN           NaN           NaN                 NaN
# 0            NaN           NaN           NaN                 NaN
# 0            NaN           NaN           NaN                 NaN
#
#    inLowComplexityRegion dannScore oneKg.allAf oneKg.afrAf oneKg.amrAf
# 0                    NaN       NaN         NaN         NaN         NaN  \
# 0                    NaN       NaN         NaN         NaN         NaN
# 0                    NaN       NaN         NaN         NaN         NaN
# 0                    NaN       NaN         NaN         NaN         NaN
# 0                    NaN       NaN         NaN         NaN         NaN
# ..                   ...       ...         ...         ...         ...
# 0                    NaN      0.75         NaN         NaN         NaN
# 0                    NaN      0.85         NaN         NaN         NaN
# 0                    NaN      0.85         NaN         NaN         NaN
# 0                    NaN      0.58         NaN         NaN         NaN
# 0                    NaN      0.58         NaN         NaN         NaN
#
#    oneKg.easAf oneKg.eurAf oneKg.sasAf  oneKg.allAn  oneKg.afrAn  oneKg.amrAn
# 0          NaN         NaN         NaN          NaN          NaN          NaN  \
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# ..         ...         ...         ...          ...          ...          ...
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 0          NaN         NaN         NaN          NaN          NaN          NaN
# 0          NaN         NaN         NaN          NaN          NaN          NaN
#
#     oneKg.easAn  oneKg.eurAn  oneKg.sasAn  oneKg.allAc  oneKg.afrAc
# 0           NaN          NaN          NaN          NaN          NaN  \
# 0           NaN          NaN          NaN          NaN          NaN
# 0           NaN          NaN          NaN          NaN          NaN
# 0           NaN          NaN          NaN          NaN          NaN
# 0           NaN          NaN          NaN          NaN          NaN
# ..          ...          ...          ...          ...          ...
# 0           NaN          NaN          NaN          NaN          NaN
# 0           NaN          NaN          NaN          NaN          NaN
# 0           NaN          NaN          NaN          NaN          NaN
# 0           NaN          NaN          NaN          NaN          NaN
# 0           NaN          NaN          NaN          NaN          NaN
#
#     oneKg.amrAc  oneKg.easAc  oneKg.eurAc  oneKg.sasAc cosmic gerpScore
# 0           NaN          NaN          NaN          NaN    NaN       NaN  \
# 0           NaN          NaN          NaN          NaN    NaN       NaN
# 0           NaN          NaN          NaN          NaN    NaN       NaN
# 0           NaN          NaN          NaN          NaN    NaN       NaN
# 0           NaN          NaN          NaN          NaN    NaN       NaN
# ..          ...          ...          ...          ...    ...       ...
# 0           NaN          NaN          NaN          NaN    NaN    -0.635
# 0           NaN          NaN          NaN          NaN    NaN    -0.574
# 0           NaN          NaN          NaN          NaN    NaN    -0.574
# 0           NaN          NaN          NaN          NaN    NaN     0.622
# 0           NaN          NaN          NaN          NaN    NaN     0.622
#
#    primateAI-3D revel.score clinvar spliceAI
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
# ..          ...         ...     ...      ...
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
# 0           NaN         NaN     NaN      NaN
#
# [2472 rows x 99 columns]

# %%
positions[0].to_df("variants.transcripts")
# Out:
#   chromosome  position refAllele altAlleles filters  mappingQuality
# 0      chr21   5228221         G        [T]  [PASS]           75.75  \
#
#   cyatogeneticBand variants.transcripts vcfInfo.DP
# 0            21p12                 None       1004

# %%
positions[0].variants[0].get("transcripts")
# Out:
# [{'transcript': 'ENST00000623753.1',
#   'source': 'Ensembl',
#   'bioType': 'lncRNA',
#   'geneId': 'ENSG00000279669',
#   'hgnc': 'ENSG00000279669',
#   'consequence': ['downstream_gene_variant'],
#   'impact': 'modifier',
#   'isCanonical': True}]

# %% [markdown]
# ## Filter by Consequence

# %%
parser = Parser(annotated_data)

# %%
positions = parser.filter_transcripts_by_consequence(
    include=["non_coding_transcript_exon_variant"]
)
len(positions), positions[0].model_dump()
# Out:
# (147,
#  {'chromosome': 'chr21',
#   'position': 5232869,
#   'refAllele': 'T',
#   'altAlleles': ['G'],
#   'filters': ['base_quality', 'weak_evidence'],
#   'mappingQuality': 58.1,
#   'cytogeneticBand': '21p12',
#   'vcfInfo': {'DP': '799'},
#   'samples': [{'genotype': '0/0',
#     'variantFrequencies': [0.0552],
#     'totalDepth': 181,
#     'alleleDepths': [171, 10],
#     'somaticQuality': 0,
#     'vcfSampleInfo': {'F1R2': '96,6', 'F2R1': '75,4'}},
#    {'genotype': '0/1',
#     'variantFrequencies': [0.0677],
#     'totalDepth': 591,
#     'alleleDepths': [551, 40],
#     'somaticQuality': 8.6,
#     'vcfSampleInfo': {'F1R2': '280,23', 'F2R1': '271,17'}}],
#   'variants': [{'vid': '21-5232869-T-G',
#     'chromosome': 'chr21',
#     'begin': 5232869,
#     'end': 5232869,
#     'refAllele': 'T',
#     'altAllele': 'G',
#     'variantType': 'SNV',
#     'hgvsg': 'NC_000021.9:g.5232869T>G',
#     'phylopScore': 0.5,
#     'transcripts': [{'transcript': 'ENST00000623753.1',
#       'source': 'Ensembl',
#       'bioType': 'lncRNA',
#       'cdnaPos': '187',
#       'exons': '2/2',
#       'geneId': 'ENSG00000279669',
#       'hgnc': 'ENSG00000279669',
#       'consequence': ['non_coding_transcript_exon_variant'],
#       'impact': 'modifier',
#       'hgvsc': 'ENST00000623753.1:n.187A>C',
#       'isCanonical': True}]}]})

# %%
positions = parser.filter_transcripts_by_consequence(
    exclude=["downstream_gene_variant", "upstream_gene_variant"]
)
len(positions), positions[0].model_dump()
# Out:
# (11723,
#  {'chromosome': 'chr21',
#   'position': 5232869,
#   'refAllele': 'T',
#   'altAlleles': ['G'],
#   'filters': ['base_quality', 'weak_evidence'],
#   'mappingQuality': 58.1,
#   'cytogeneticBand': '21p12',
#   'vcfInfo': {'DP': '799'},
#   'samples': [{'genotype': '0/0',
#     'variantFrequencies': [0.0552],
#     'totalDepth': 181,
#     'alleleDepths': [171, 10],
#     'somaticQuality': 0,
#     'vcfSampleInfo': {'F1R2': '96,6', 'F2R1': '75,4'}},
#    {'genotype': '0/1',
#     'variantFrequencies': [0.0677],
#     'totalDepth': 591,
#     'alleleDepths': [551, 40],
#     'somaticQuality': 8.6,
#     'vcfSampleInfo': {'F1R2': '280,23', 'F2R1': '271,17'}}],
#   'variants': [{'vid': '21-5232869-T-G',
#     'chromosome': 'chr21',
#     'begin': 5232869,
#     'end': 5232869,
#     'refAllele': 'T',
#     'altAllele': 'G',
#     'variantType': 'SNV',
#     'hgvsg': 'NC_000021.9:g.5232869T>G',
#     'phylopScore': 0.5,
#     'transcripts': [{'transcript': 'ENST00000623753.1',
#       'source': 'Ensembl',
#       'bioType': 'lncRNA',
#       'cdnaPos': '187',
#       'exons': '2/2',
#       'geneId': 'ENSG00000279669',
#       'hgnc': 'ENSG00000279669',
#       'consequence': ['non_coding_transcript_exon_variant'],
#       'impact': 'modifier',
#       'hgvsc': 'ENST00000623753.1:n.187A>C',
#       'isCanonical': True}]}]})

# %% [markdown]
# ## Filter by gnomad frequency
# Possible values
#
# 'coverage', 'failedFilter', 'allAf', 'allAn', 'allAc', 'allHc', 'afrAf', 'afrAn', 'afrAc', 'afrHc', 'amrAf', 'amrAn', 'amrAc', 'amrHc', 'easAf', 'easAn', 'easAc', 'easHc', 'finAf', 'finAn', 'finAc', 'finHc', 'nfeAf', 'nfeAn', 'nfeAc', 'nfeHc', 'asjAf', 'asjAn', 'asjAc', 'asjHc', 'sasAf', 'sasAn', 'sasAc', 'sasHc', 'othAf', 'othAn', 'othAc', 'othHc', 'maleAf', 'maleAn', 'maleAc', 'maleHc', 'femaleAf', 'femaleAn', 'femaleAc', 'femaleHc', 'controlsAllAf', 'controlsAllAn', 'controlsAllAc'

# %%
parser = Parser(annotated_data)

# %%
positions = parser.get_variants_above_gnomad_freq(frequency_key="allAf", frequency_threshold_high=0.1)
len(positions), positions[0].model_dump()
# Out:
# (851,
#  {'chromosome': 'chr21',
#   'position': 5222289,
#   'refAllele': 'C',
#   'altAlleles': ['T'],
#   'filters': ['mapping_quality', 'weak_evidence'],
#   'mappingQuality': 49.7,
#   'cytogeneticBand': '21p12',
#   'vcfInfo': {'DP': '749'},
#   'samples': [{'genotype': '0/0',
#     'variantFrequencies': [0.0219],
#     'totalDepth': 137,
#     'alleleDepths': [134, 3],
#     'somaticQuality': 0,
#     'vcfSampleInfo': {'F1R2': '77,3', 'F2R1': '57,0'}},
#    {'genotype': '0/1',
#     'variantFrequencies': [0.0196],
#     'totalDepth': 562,
#     'alleleDepths': [551, 11],
#     'somaticQuality': 7,
#     'vcfSampleInfo': {'F1R2': '286,6', 'F2R1': '265,5'}}],
#   'variants': [{'vid': '21-5222289-C-T',
#     'chromosome': 'chr21',
#     'begin': 5222289,
#     'end': 5222289,
#     'refAllele': 'C',
#     'altAllele': 'T',
#     'variantType': 'SNV',
#     'hgvsg': 'NC_000021.9:g.5222289C>T',
#     'phylopScore': -0.2,
#     'dbsnp': ['rs1366179382'],
#     'gnomad': {'coverage': 3,
#      'allAf': 0.000502,
#      'allAn': 149274,
#      'allAc': 75,
#      'allHc': 0,
#      'afrAf': 0.001704,
#      'afrAn': 40502,
#      'afrAc': 69,
#      'afrHc': 0,
#      'amrAf': 6.7e-05,
#      'amrAn': 14966,
#      'amrAc': 1,
#      'amrHc': 0,
#      'easAf': 0,
#      'easAn': 5022,
#      'easAc': 0,
#      'easHc': 0,
#      'finAf': 0,
#      'finAn': 10430,
#      'finAc': 0,
#      'finHc': 0,
#      'nfeAf': 7.5e-05,
#      'nfeAn': 66950,
#      'nfeAc': 5,
#      'nfeHc': 0,
#      'asjAf': 0,
#      'asjAn': 3438,
#      'asjAc': 0,
#      'asjHc': 0,
#      'sasAf': 0,
#      'sasAn': 4734,
#      'sasAc': 0,
#      'sasHc': 0,
#      'othAf': 0,
#      'othAn': 2024,
#      'othAc': 0,
#      'othHc': 0,
#      'maleAf': 0.000411,
#      'maleAn': 73006,
#      'maleAc': 30,
#      'maleHc': 0,
#      'femaleAf': 0.00059,
#      'femaleAn': 76268,
#      'femaleAc': 45,
#      'femaleHc': 0,
#      'controlsAllAf': 0.000565,
#      'controlsAllAn': 31850,
#      'controlsAllAc': 18},
#     'topmed': {'allAf': 0.001091,
#      'allAn': 125568,
#      'allAc': 137,
#      'allHc': 0,
#      'failedFilter': True},
#     'phyloPPrimateScore': 0.074}]})

# %%
positions = parser.get_variants_above_gnomad_freq(frequency_key="allAf", frequency_threshold_low=0.1)
len(positions), positions[0].model_dump()
# Out:
# (302,
#  {'chromosome': 'chr21',
#   'position': 5227548,
#   'refAllele': 'C',
#   'altAlleles': ['T'],
#   'filters': ['PASS'],
#   'mappingQuality': 93.13,
#   'cytogeneticBand': '21p12',
#   'vcfInfo': {'DP': '314'},
#   'samples': [{'genotype': '0|0',
#     'variantFrequencies': [0.125],
#     'totalDepth': 40,
#     'alleleDepths': [35, 5],
#     'somaticQuality': 0,
#     'vcfSampleInfo': {'F1R2': '16,4', 'F2R1': '19,1'}},
#    {'genotype': '0|1',
#     'variantFrequencies': [0.3432],
#     'totalDepth': 169,
#     'alleleDepths': [111, 58],
#     'somaticQuality': 28.1,
#     'vcfSampleInfo': {'F1R2': '60,29', 'F2R1': '51,29'}}],
#   'variants': [{'vid': '21-5227548-C-T',
#     'chromosome': 'chr21',
#     'begin': 5227548,
#     'end': 5227548,
#     'refAllele': 'C',
#     'altAllele': 'T',
#     'variantType': 'SNV',
#     'hgvsg': 'NC_000021.9:g.5227548C>T',
#     'phylopScore': 0.2,
#     'inLowComplexityRegion': True,
#     'dbsnp': ['rs1219135472'],
#     'gnomad': {'coverage': 15,
#      'allAf': 0.348842,
#      'allAn': 65554,
#      'allAc': 22868,
#      'allHc': 4287,
#      'afrAf': 0.195536,
#      'afrAn': 16130,
#      'afrAc': 3154,
#      'afrHc': 157,
#      'amrAf': 0.38877,
#      'amrAn': 5628,
#      'amrAc': 2188,
#      'amrHc': 454,
#      'easAf': 0.258838,
#      'easAn': 2376,
#      'easAc': 615,
#      'easHc': 84,
#      'finAf': 0.511703,
#      'finAn': 2478,
#      'finAc': 1268,
#      'finHc': 372,
#      'nfeAf': 0.406416,
#      'nfeAn': 33980,
#      'nfeAc': 13810,
#      'nfeHc': 2911,
#      'asjAf': 0.357451,
#      'asjAn': 1852,
#      'asjAc': 662,
#      'asjHc': 100,
#      'sasAf': 0.371722,
#      'sasAn': 1754,
#      'sasAc': 652,
#      'sasHc': 107,
#      'othAf': 0.363636,
#      'othAn': 880,
#      'othAc': 320,
#      'othHc': 60,
#      'maleAf': 0.348586,
#      'maleAn': 30136,
#      'maleAc': 10505,
#      'maleHc': 2007,
#      'femaleAf': 0.34906,
#      'femaleAn': 35418,
#      'femaleAc': 12363,
#      'femaleHc': 2280,
#      'controlsAllAf': 0.338529,
#      'controlsAllAn': 11804,
#      'controlsAllAc': 3996},
#     'topmed': {'allAf': 0.499148,
#      'allAn': 125568,
#      'allAc': 62677,
#      'allHc': 0,
#      'failedFilter': True},
#     'phyloPPrimateScore': 0}]})

# %%
positions = parser.get_variants_above_gnomad_freq(frequency_key="allAf", frequency_threshold_low=0.1, frequency_threshold_high=0.2)
len(positions), positions[0].model_dump()
# Out:
# (114,
#  {'chromosome': 'chr21',
#   'position': 5278225,
#   'refAllele': 'A',
#   'altAlleles': ['T'],
#   'filters': ['alt_allele_in_normal',
#    'filtered_reads',
#    'mapping_quality',
#    'non_homref_normal',
#    'weak_evidence'],
#   'mappingQuality': 12.91,
#   'cytogeneticBand': '21p12',
#   'vcfInfo': {'DP': '113'},
#   'samples': [{'genotype': '0/0',
#     'variantFrequencies': [0.25],
#     'totalDepth': 12,
#     'alleleDepths': [9, 3],
#     'somaticQuality': 0.5,
#     'vcfSampleInfo': {'F1R2': '5,2', 'F2R1': '4,1'}},
#    {'genotype': '0/1',
#     'variantFrequencies': [0.7931],
#     'totalDepth': 29,
#     'alleleDepths': [6, 23],
#     'somaticQuality': 7.5,
#     'vcfSampleInfo': {'F1R2': '4,9', 'F2R1': '2,14'}}],
#   'variants': [{'vid': '21-5278225-A-T',
#     'chromosome': 'chr21',
#     'begin': 5278225,
#     'end': 5278225,
#     'refAllele': 'A',
#     'altAllele': 'T',
#     'variantType': 'SNV',
#     'hgvsg': 'NC_000021.9:g.5278225A>T',
#     'dbsnp': ['rs1171728286'],
#     'gnomad': {'coverage': 7,
#      'failedFilter': True,
#      'allAf': 0.148668,
#      'allAn': 46856,
#      'allAc': 6966,
#      'allHc': 80,
#      'afrAf': 0.181794,
#      'afrAn': 26244,
#      'afrAc': 4771,
#      'afrHc': 46,
#      'amrAf': 0.110039,
#      'amrAn': 2590,
#      'amrAc': 285,
#      'amrHc': 5,
#      'easAf': 0.000608,
#      'easAn': 1644,
#      'easAc': 1,
#      'easHc': 0,
#      'finAf': 0.050104,
#      'finAn': 958,
#      'finAc': 48,
#      'finHc': 0,
#      'nfeAf': 0.122751,
#      'nfeAn': 12448,
#      'nfeAc': 1528,
#      'nfeHc': 26,
#      'asjAf': 0.225636,
#      'asjAn': 944,
#      'asjAc': 213,
#      'asjHc': 2,
#      'sasAf': 0.022059,
#      'sasAn': 1224,
#      'sasAc': 27,
#      'sasHc': 0,
#      'othAf': 0.116838,
#      'othAn': 582,
#      'othAc': 68,
#      'othHc': 0,
#      'maleAf': 0.145535,
#      'maleAn': 22084,
#      'maleAc': 3214,
#      'maleHc': 34,
#      'femaleAf': 0.151461,
#      'femaleAn': 24772,
#      'femaleAc': 3752,
#      'femaleHc': 46,
#      'controlsAllAf': 0.128554,
#      'controlsAllAn': 9848,
#      'controlsAllAc': 1266},
#     'topmed': {'allAf': 0.084209,
#      'allAn': 125568,
#      'allAc': 10574,
#      'allHc': 0,
#      'failedFilter': True}}]})

# %% [markdown]
# ## Gene Filtering

# %%
annotated_data.genes
# Out:
#            name   hgncId ncbiGeneId    ensemblGeneId
# 0         AATBC  51526.0     284837  ENSG00000215458  \
# 1        ABCC13      NaN        NaN  ENSG00000291052
# 2        ABCC13  16022.0     150000  ENSG00000243064
# 3         ABCG1     73.0       9619  ENSG00000160179
# 4        ADARB1    226.0        104  ENSG00000197381
# ..          ...      ...        ...              ...
# 437        YBEY   1299.0      54059  ENSG00000182362
# 438      YRDCP3  39921.0  100861429  ENSG00000230859
# 439      ZBTB21  13083.0      49854  ENSG00000173276
# 440  ZNF295-AS1  23130.0     150142  ENSG00000237232
# 441     ZNF355P  17218.0  100505852  ENSG00000168122
#
#                                                   omim
# 0                                                  NaN  \
# 1    [{'mimNumber': 608835, 'geneName': 'ATP-bindin...
# 2    [{'mimNumber': 608835, 'geneName': 'ATP-bindin...
# 3    [{'mimNumber': 603076, 'geneName': 'ATP-bindin...
# 4    [{'mimNumber': 601218, 'geneName': 'Adenosine ...
# ..                                                 ...
# 437  [{'mimNumber': 617461, 'geneName': 'YBEY metal...
# 438                                                NaN
# 439  [{'mimNumber': 616485, 'geneName': 'Zinc finge...
# 440                                                NaN
# 441                                                NaN
#
#                                                 gnomAD
# 0                                                  NaN  \
# 1                                                  NaN
# 2                                                  NaN
# 3    {'pLi': 0.112, 'pRec': 0.888, 'pNull': 9.34e-0...
# 4    {'pLi': 0.803, 'pRec': 0.197, 'pNull': 8.32e-0...
# ..                                                 ...
# 437  {'pLi': 1.34e-07, 'pRec': 0.0625, 'pNull': 0.9...
# 438                                                NaN
# 439  {'pLi': 0.998, 'pRec': 0.00222, 'pNull': 5.45e...
# 440                                                NaN
# 441                                                NaN
#
#     clingenDosageSensitivityMap clingenGeneValidity cosmic
# 0                           NaN                 NaN    NaN
# 1                           NaN                 NaN    NaN
# 2                           NaN                 NaN    NaN
# 3                           NaN                 NaN    NaN
# 4                           NaN                 NaN    NaN
# ..                          ...                 ...    ...
# 437                         NaN                 NaN    NaN
# 438                         NaN                 NaN    NaN
# 439                         NaN                 NaN    NaN
# 440                         NaN                 NaN    NaN
# 441                         NaN                 NaN    NaN
#
# [442 rows x 9 columns]

# %%
annotated_data.genes[annotated_data.genes["name"] == "ABCC13"]
# Out:
#      name   hgncId ncbiGeneId    ensemblGeneId
# 1  ABCC13      NaN        NaN  ENSG00000291052  \
# 2  ABCC13  16022.0     150000  ENSG00000243064
#
#                                                 omim gnomAD
# 1  [{'mimNumber': 608835, 'geneName': 'ATP-bindin...    NaN  \
# 2  [{'mimNumber': 608835, 'geneName': 'ATP-bindin...    NaN
#
#   clingenDosageSensitivityMap clingenGeneValidity cosmic
# 1                         NaN                 NaN    NaN
# 2                         NaN                 NaN    NaN

# %%
annotated_data.genes[annotated_data.genes["ensemblGeneId"].isin(["ENSG00000173276", "ENSG00000243064"])]
# Out:
#        name   hgncId ncbiGeneId    ensemblGeneId
# 2    ABCC13  16022.0     150000  ENSG00000243064  \
# 439  ZBTB21  13083.0      49854  ENSG00000173276
#
#                                                   omim
# 2    [{'mimNumber': 608835, 'geneName': 'ATP-bindin...  \
# 439  [{'mimNumber': 616485, 'geneName': 'Zinc finge...
#
#                                                 gnomAD
# 2                                                  NaN  \
# 439  {'pLi': 0.998, 'pRec': 0.00222, 'pNull': 5.45e...
#
#     clingenDosageSensitivityMap clingenGeneValidity cosmic
# 2                           NaN                 NaN    NaN
# 439                         NaN                 NaN    NaN

# %%
annotated_data.genes.dropna(subset=["cosmic"])
# Out:
#         name   hgncId ncbiGeneId    ensemblGeneId
# 198      ERG   3446.0       2078  ENSG00000157554  \
# 418  TMPRSS2  11876.0       7113  ENSG00000184012
#
#                                                   omim
# 198  [{'mimNumber': 165080, 'geneName': 'ETS transc...  \
# 418  [{'mimNumber': 602060, 'geneName': 'Transmembr...
#
#                                                 gnomAD
# 198  {'pLi': 0.964, 'pRec': 0.0359, 'pNull': 5.03e-...  \
# 418  {'pLi': 2.4e-10, 'pRec': 0.88, 'pNull': 0.12, ...
#
#     clingenDosageSensitivityMap clingenGeneValidity
# 198                         NaN                 NaN  \
# 418                         NaN                 NaN
#
#                                        cosmic
# 198  {'roleInCancer': ['oncogene', 'fusion']}
# 418              {'roleInCancer': ['fusion']}
